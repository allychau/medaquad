# %%
# %matplotlib notebook

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
covi_df = pd.read_csv('ucb-ber-data-pt-06-2020-u-c/covi.csv')
covi_df.head()
# Out:
#   Postal Code        Name    Poverty     Covid
# 0          AL     Alabama   814197.0   83782.0
# 1          AK      Alaska    71916.0    2729.0
# 2          AZ     Arizona  1107153.0  168273.0
# 3          AR    Arkansas   497388.0   40181.0
# 4          CA  California  5527621.0  474819.0

# %%
covi_df = covi_df.set_index('Postal Code')

covi_df.head()
# Out:
#                    Name    Poverty     Covid
# Postal Code
# AL              Alabama   814197.0   83782.0
# AK               Alaska    71916.0    2729.0
# AZ              Arizona  1107153.0  168273.0
# AR             Arkansas   497388.0   40181.0
# CA           California  5527621.0  474819.0

# %%
covi_df.plot(kind="scatter", x="Poverty", y="Covid", grid=True, figsize=(5,5),
              title="Poverty v Covid-19")
# Out:
# <img src="data:image/png;base64,..." width="500">
