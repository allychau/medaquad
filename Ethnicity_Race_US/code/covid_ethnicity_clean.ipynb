# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import csv

# %%
covid_data_file1 = '../data/covid_race_data_tracker.csv'
covid_tracker_df = pd.read_csv(covid_data_file1, dtype="object", encoding="utf-8")
covid_tracker_df.head(100)
# Out:
#         Date State Cases_Total Cases_White Cases_Black Cases_LatinX  \
# 0   20200722    AK        2132         750          49          NaN
# 1   20200722    AL       71813       22694       20884          NaN
# 2   20200722    AR       35246       17406        7521          NaN
# 3   20200722    AS         NaN         NaN         NaN          NaN
# 4   20200722    AZ      150609       24130        3246        34645
# ..       ...   ...         ...         ...         ...          ...
# 95  20200719    OK       25265       14214        1875          NaN
# 96  20200719    OR       14579        5710         561          NaN
# 97  20200719    PA      101027       32200       13700          NaN
# 98  20200719    PR       12063         NaN         NaN          NaN
# 99  20200719    RI       17793        4878        1629         6072
#
#    Cases_Asian Cases_AIAN Cases_NHPI Cases_Multiracial  ... Deaths_LatinX  \
# 0           67        282         76                61  ...           NaN
# 1          267        NaN        NaN               NaN  ...           NaN
# 2          498        101       1985               NaN  ...           NaN
# 3          NaN        NaN        NaN               NaN  ...           NaN
# 4         1096       9085        NaN               NaN  ...           786
# ..         ...        ...        ...               ...  ...           ...
# 95        1528       1809        NaN               NaN  ...           NaN
# 96         454        299        360               329  ...           NaN
# 97        1400        NaN        NaN               NaN  ...           NaN
# 98         NaN        NaN        NaN               NaN  ...           NaN
# 99         NaN        NaN        NaN               NaN  ...            85
#
#    Deaths_Asian Deaths_AIAN Deaths_NHPI Deaths_Multiracial Deaths_Other  \
# 0             2           4           1                  0            0
# 1             4         NaN         NaN                NaN           27
# 2             6           0          30                NaN           27
# 3           NaN         NaN         NaN                NaN          NaN
# 4            32         394         NaN                NaN           53
# ..          ...         ...         ...                ...          ...
# 95           10          37         NaN                NaN           11
# 96           10           3           6                  2           20
# 97          151         NaN         NaN                NaN          339
# 98          NaN         NaN         NaN                NaN          NaN
# 99          NaN         NaN         NaN                NaN           13
#
#    Deaths_Unknown Deaths_Ethnicity_Hispanic Deaths_Ethnicity_NonHispanic  \
# 0               1                         0                           18
# 1             100                        45                         1126
# 2               3                        41                          336
# 3             NaN                       NaN                          NaN
# 4             495                       786                         1693
# ..            ...                       ...                          ...
# 95             24                        19                          390
# 96             25                        31                          199
# 97             23                       418                         6574
# 98            178                       NaN                          NaN
# 99            185                        85                          720
#
#    Deaths_Ethnicity_Unknown
# 0                         1
# 1                       193
# 2                         3
# 3                       NaN
# 4                       495
# ..                      ...
# 95                       42
# 96                       30
# 97                       23
# 98                      NaN
# 99                      185
#
# [100 rows x 28 columns]

# %%
# Out:
#         Date State Cases_Total Cases_White Cases_Black Cases_LatinX  \
# 0   20200722    AK        2132         750          49          NaN
# 1   20200722    AL       71813       22694       20884          NaN
# 2   20200722    AR       35246       17406        7521          NaN
# 3   20200722    AS         NaN         NaN         NaN          NaN
# 4   20200722    AZ      150609       24130        3246        34645
# 5   20200722    CA      413576       46562       11396       146903
# 6   20200722    CO       41698       12771        1874        13897
# 7   20200722    CT       48223       17226        6375         9249
# 8   20200722    DC       11529        2343        5637          NaN
# 9   20200722    DE       13792        4584        3529         3605
# 10  20200722    FL      379619       78227       52834        93126
# 11  20200722    GA      152302       35048       39008        20562
# 12  20200722    GU         332          35         NaN          NaN
# 13  20200722    HI        1435         221          10          NaN
# 14  20200722    IA       40081       26456        3206          NaN
# 15  20200722    ID       16322        7861         207          NaN
# 16  20200722    IL      166476       37393       27704        50999
# 17  20200722    IN       58673       26963        6696          NaN
# 18  20200722    KS       24104       15587        1780          NaN
# 19  20200722    KY       24540       12843        2044          NaN
# 20  20200722    LA       99354       31163       36693          NaN
# 21  20200722    MA      114320       35350       10731        22344
# 22  20200722    MD       80172       16887       23503        20505
# 23  20200722    ME        3723        2253         848          NaN
# 24  20200722    MI       83730       34385       22633          NaN
# 25  20200722    MN       47961       21457        9842          NaN
# 26  20200722    MO       36063       16950        8294          NaN
# 27  20200722    MP          38         NaN         NaN          NaN
# 28  20200722    MS       47071       13476       20721         1795
# 29  20200722    MT        2813        1672          15          NaN
# 30  20200722    NC      105001       40399       17314          NaN
# 31  20200722    ND        5367         NaN         NaN          NaN
# 32  20200722    NE       23486       13600        1400          NaN
# 33  20200722    NH        6295        4012         325          657
# 34  20200722    NJ      177645       38813       18328        32730
# 35  20200722    NM       17828        2347         324         6722
# 36  20200722    NV       38657        7023        1949         7920
# 37  20200722    NY      408886         NaN         NaN          NaN
# 38  20200722    OH       78742       37618       20518          NaN
# 39  20200722    OK       27301       15339        2001          NaN
# 40  20200722    OR       15393        6378         589          NaN
# 41  20200722    PA      103396       32200       14000          NaN
# 42  20200722    PR       13038         NaN         NaN          NaN
# 43  20200722    RI       18062        4939        1671         6171
# 44  20200722    SC       75042       24682       18100          NaN
# 45  20200722    SD        8077        3071         995         1162
# 46  20200722    TN       84417       35281       16107          NaN
# 47  20200722    TX      351618        7428        3491        11999
# 48  20200722    UT       35578       13808         886        13994
# 49  20200722    VA       80393       17960       13324        24824
# 50  20200722    VI         336         NaN         NaN          NaN
# 51  20200722    VT        1366        1124         151          NaN
# 52  20200722    WA       49247       11704        1743        13990
# 53  20200722    WI       48583       29339        7478          NaN
# 54  20200722    WV        5461        4290         411          NaN
# 55  20200722    WY        2288        1088          22          294
#
#    Cases_Asian Cases_AIAN Cases_NHPI Cases_Multiracial  ... Deaths_LatinX  \
# 0           67        282         76                61  ...           NaN
# 1          267        NaN        NaN               NaN  ...           NaN
# 2          498        101       1985               NaN  ...           NaN
# 3          NaN        NaN        NaN               NaN  ...           NaN
# 4         1096       9085        NaN               NaN  ...           786
# 5        14920        587       1590              1967  ...          3455
# 6          840        204        127               381  ...           361
# 7          695         44        NaN               143  ...           380
# 8          178         27         30               NaN  ...            76
# 9          192        NaN        NaN               NaN  ...            35
# 10         NaN        NaN        NaN               NaN  ...          1358
# 11        1837         89        153               NaN  ...           196
# 12         126        NaN        128               NaN  ...           NaN
# 13         382        NaN        405               NaN  ...           NaN
# 14        2004        400        400               NaN  ...           NaN
# 15         140        119         46               563  ...           NaN
# 16        4497        230        395               NaN  ...          1531
# 17         774        NaN        NaN               NaN  ...           NaN
# 18         888        166        NaN               NaN  ...           NaN
# 19         480         77         37               965  ...           NaN
# 20        4463        217        115               NaN  ...           NaN
# 21        2409        NaN        NaN               NaN  ...           586
# 22        1532        NaN        NaN               NaN  ...           388
# 23          95          7          2                25  ...           NaN
# 24        1691        323        NaN              5558  ...           NaN
# 25        3153        405        107               807  ...           NaN
# 26         NaN        NaN        NaN              1082  ...           NaN
# 27         NaN        NaN        NaN               NaN  ...           NaN
# 28         149       1165        NaN               NaN  ...            24
# 29           8        318        NaN               NaN  ...           NaN
# 30        1301        911        210               NaN  ...           NaN
# 31         NaN        NaN        NaN               NaN  ...           NaN
# 32        1300        256         33               NaN  ...           NaN
# 33         164        NaN        NaN               NaN  ...            11
# 34        5437        NaN        NaN               NaN  ...          2730
# 35         123       7159        NaN               NaN  ...            59
# 36        1735        107        NaN               NaN  ...           102
# 37         NaN        NaN        NaN               NaN  ...          6665
# 38        2149         95        147              2359  ...           NaN
# 39        1556       2099        NaN               NaN  ...           NaN
# 40         491        350        377               342  ...           NaN
# 41        1500        NaN        NaN               NaN  ...           NaN
# 42         NaN        NaN        NaN               NaN  ...           NaN
# 43         NaN        NaN        NaN               NaN  ...            85
# 44         548        NaN        NaN               NaN  ...           NaN
# 45         716       1320        NaN               NaN  ...           NaN
# 46         832         97         69               NaN  ...           NaN
# 47         671        NaN        NaN               NaN  ...           229
# 48         799        769       1387               NaN  ...            63
# 49        2460         96        NaN               289  ...           226
# 50         NaN        NaN        NaN               NaN  ...           NaN
# 51          53          2        NaN               NaN  ...           NaN
# 52        1715        509        953               699  ...           198
# 53        1574        460        NaN               NaN  ...           NaN
# 54         NaN        NaN        NaN               NaN  ...           NaN
# 55          11        367          7               NaN  ...             2
#
#    Deaths_Asian Deaths_AIAN Deaths_NHPI Deaths_Multiracial Deaths_Other  \
# 0             2           4           1                  0            0
# 1             4         NaN         NaN                NaN           27
# 2             6           0          30                NaN           27
# 3           NaN         NaN         NaN                NaN          NaN
# 4            32         394         NaN                NaN           53
# 5          1008          27          41                 41           93
# 6            53          11           5                 20            6
# 7            48           2         NaN                 32           21
# 8             8         NaN         NaN                NaN            6
# 9             1         NaN         NaN                NaN            6
# 10          NaN         NaN         NaN                NaN          185
# 11           53           5           7                NaN           15
# 12          NaN         NaN         NaN                NaN          NaN
# 13          NaN         NaN         NaN                NaN          NaN
# 14           24           8           8                NaN            0
# 15            2           2         NaN                NaN            1
# 16          349          10           9                NaN           51
# 17           14         NaN         NaN                NaN          359
# 18            9           2         NaN                NaN            9
# 19            8           0         NaN                 16          NaN
# 20           23           4           5                NaN           18
# 21          218         NaN         NaN                NaN          545
# 22          131         NaN         NaN                NaN           36
# 23          NaN         NaN         NaN                NaN            0
# 24           80          19         NaN                103          122
# 25           67          31           3                 22           20
# 26          NaN         NaN         NaN                 10           32
# 27          NaN         NaN         NaN                NaN          NaN
# 28            0          76         NaN                NaN           16
# 29          NaN          10         NaN                NaN          NaN
# 30           25          25           4                NaN          106
# 31          NaN         NaN         NaN                NaN          NaN
# 32           18           7           0                NaN           12
# 33            4         NaN         NaN                NaN            1
# 34          745         NaN         NaN                NaN          243
# 35            1         236         NaN                NaN          NaN
# 36           82           4         NaN                NaN           11
# 37         1683         NaN         NaN                NaN         1842
# 38           36           1           1                 39           24
# 39           11          42         NaN                NaN           11
# 40           12           3           6                  2           23
# 41          151         NaN         NaN                NaN          339
# 42          NaN         NaN         NaN                NaN          NaN
# 43          NaN         NaN         NaN                NaN           13
# 44           11         NaN         NaN                NaN           34
# 45          NaN         NaN         NaN                NaN          NaN
# 46           15           0           2                NaN           55
# 47           15         NaN         NaN                NaN            1
# 48           13          21          14                NaN           22
# 49          117           2         NaN                  0           29
# 50          NaN         NaN         NaN                NaN          NaN
# 51            2         NaN         NaN                NaN            1
# 52          123          31          16                 17           33
# 53           23          10         NaN                NaN           15
# 54          NaN         NaN         NaN                NaN          NaN
# 55            0          10         NaN                NaN            0
#
#    Deaths_Unknown Deaths_Ethnicity_Hispanic Deaths_Ethnicity_NonHispanic  \
# 0               1                         0                           18
# 1             100                        45                         1126
# 2               3                        41                          336
# 3             NaN                       NaN                          NaN
# 4             495                       786                         1693
# 5             198                      3455                         4217
# 6              53                       361                         1224
# 7              42                       380                         3984
# 8               0                        76                          504
# 9              23                        35                          469
# 10            340                      1358                         3502
# 11             40                       196                         3074
# 12              5                       NaN                          NaN
# 13             25                       NaN                          NaN
# 14             81                        56                          657
# 15              0                        14                          117
# 16            298                      1531                         5711
# 17            393                        53                         1395
# 18              8                        40                          255
# 19             46                        25                          577
# 20            138                        73                         3303
# 21             60                       586                         7822
# 22             12                       388                         3005
# 23              9                         0                           98
# 24            221                       127                         5302
# 25             58                        67                         1460
# 26             44                        32                          987
# 27              2                       NaN                          NaN
# 28             10                        24                         1272
# 29             15                       NaN                          NaN
# 30             57                       166                         1410
# 31             88                       NaN                          NaN
# 32             14                        74                          202
# 33              2                        11                          389
# 34           2187                      2730                        10790
# 35            193                        59                          339
# 36            147                       102                          455
# 37           3016                      6665                        18451
# 38             53                        71                         3077
# 39             25                        21                          407
# 40             22                        34                          210
# 41             71                       418                         6574
# 42            185                       NaN                          NaN
# 43            186                        85                          726
# 44            185                        44                          928
# 45            119                       NaN                          NaN
# 46              8                        83                          793
# 47           3679                       229                          440
# 48             13                        63                          184
# 49             81                       226                         1744
# 50              7                       NaN                          NaN
# 51              0                         0                           56
# 52             55                       198                         1215
# 53             14                       104                          755
# 54             41                       NaN                          NaN
# 55              0                         2                           22
#
#    Deaths_Ethnicity_Unknown
# 0                         1
# 1                       193
# 2                         3
# 3                       NaN
# 4                       495
# 5                       198
# 6                        53
# 7                        42
# 8                         0
# 9                        23
# 10                      599
# 11                       65
# 12                        5
# 13                      NaN
# 14                       97
# 15                        4
# 16                      105
# 17                     1218
# 18                       13
# 19                       75
# 20                      294
# 21                       60
# 22                       12
# 23                       20
# 24                      958
# 25                       65
# 26                      139
# 27                      NaN
# 28                      127
# 29                      NaN
# 30                      122
# 31                      NaN
# 32                       35
# 33                        2
# 34                     2187
# 35                      193
# 36                      147
# 37                     3016
# 38                       87
# 39                       46
# 40                       27
# 41                       71
# 42                      NaN
# 43                      186
# 44                      311
# 45                      NaN
# 46                       12
# 47                     3679
# 48                       13
# 49                       81
# 50                      NaN
# 51                        0
# 52                       55
# 53                       13
# 54                      NaN
# 55                        0
#
# [56 rows x 28 columns]

# %%
covid_tracker_df.columns
# Out:
# Index(['Date', 'State', 'Cases_Total', 'Cases_White', 'Cases_Black',
#        'Cases_LatinX', 'Cases_Asian', 'Cases_AIAN', 'Cases_NHPI',
#        'Cases_Multiracial', 'Cases_Other', 'Cases_Unknown',
#        'Cases_Ethnicity_Hispanic', 'Cases_Ethnicity_NonHispanic',
#        'Cases_Ethnicity_Unknown', 'Deaths_Total', 'Deaths_White',
#        'Deaths_Black', 'Deaths_LatinX', 'Deaths_Asian', 'Deaths_AIAN',
#        'Deaths_NHPI', 'Deaths_Multiracial', 'Deaths_Other', 'Deaths_Unknown',
#        'Deaths_Ethnicity_Hispanic', 'Deaths_Ethnicity_NonHispanic',
#        'Deaths_Ethnicity_Unknown'],
#       dtype='object')

# %%
type(covid_tracker_df['Cases_Total'][0])
# Out:
# str

# %%
# Check for 'NaN' and if true, replace them with value 0
check_for_nan = covid_tracker_df['Cases_Total'].isnull().values.any()
print (check_for_nan)
# Out:
# False

# %%
covid_tracker_df['Cases_Total'] = covid_tracker_df['Cases_Total'].fillna(0)
covid_tracker_df['Cases_White'] = covid_tracker_df['Cases_White'].fillna(0)
covid_tracker_df['Cases_Black'] = covid_tracker_df['Cases_Black'].fillna(0)
covid_tracker_df['Cases_LatinX'] = covid_tracker_df['Cases_LatinX'].fillna(0)
covid_tracker_df['Cases_Asian'] = covid_tracker_df['Cases_Asian'].fillna(0)
covid_tracker_df['Cases_AIAN'] = covid_tracker_df['Cases_AIAN'].fillna(0)
covid_tracker_df['Cases_NHPI'] = covid_tracker_df['Cases_NHPI'].fillna(0)
covid_tracker_df['Cases_Multiracial'] = covid_tracker_df['Cases_Multiracial'].fillna(0)
covid_tracker_df['Cases_Other'] = covid_tracker_df['Cases_Other'].fillna(0)
covid_tracker_df['Cases_Unknown'] = covid_tracker_df['Cases_Unknown'].fillna(0)
covid_tracker_df['Cases_Ethnicity_Hispanic'] = covid_tracker_df['Cases_Ethnicity_Hispanic'].fillna(0)
covid_tracker_df['Cases_Ethnicity_NonHispanic'] = covid_tracker_df['Cases_Ethnicity_NonHispanic'].fillna(0)
covid_tracker_df['Cases_Ethnicity_Unknown'] = covid_tracker_df['Cases_Ethnicity_Unknown'].fillna(0)
covid_tracker_df['Deaths_Total'] = covid_tracker_df['Deaths_Total'].fillna(0)
covid_tracker_df['Deaths_White'] = covid_tracker_df['Deaths_White'].fillna(0)
covid_tracker_df['Deaths_Black'] = covid_tracker_df['Deaths_Black'].fillna(0)
covid_tracker_df['Deaths_LatinX'] = covid_tracker_df['Deaths_LatinX'].fillna(0)
covid_tracker_df['Deaths_Asian'] = covid_tracker_df['Deaths_Asian'].fillna(0)
covid_tracker_df['Deaths_AIAN'] = covid_tracker_df['Deaths_AIAN'].fillna(0)
covid_tracker_df['Deaths_NHPI'] = covid_tracker_df['Deaths_NHPI'].fillna(0)
covid_tracker_df['Deaths_Multiracial'] = covid_tracker_df['Deaths_Multiracial'].fillna(0)
covid_tracker_df['Deaths_Other'] = covid_tracker_df['Deaths_Other'].fillna(0)
covid_tracker_df['Deaths_Unknown'] = covid_tracker_df['Deaths_Unknown'].fillna(0)
covid_tracker_df['Deaths_Ethnicity_Hispanic'] = covid_tracker_df['Deaths_Ethnicity_Hispanic'].fillna(0)
covid_tracker_df['Deaths_Ethnicity_NonHispanic'] = covid_tracker_df['Deaths_Ethnicity_NonHispanic'].fillna(0)
covid_tracker_df['Deaths_Ethnicity_Unknown'] = covid_tracker_df['Deaths_Ethnicity_Unknown'].fillna(0)

# %%
check_for_nan = covid_tracker_df.isnull().values.any()
print (check_for_nan)
# Out:
# False

# %%
covid_tracker_df.head()
# Out:
#        Date State Cases_Total Cases_White Cases_Black Cases_LatinX  \
# 0  20200722    AK        2132         750          49            0
# 1  20200722    AL       71813       22694       20884            0
# 2  20200722    AR       35246       17406        7521            0
# 3  20200722    AS           0           0           0            0
# 4  20200722    AZ      150609       24130        3246        34645
#
#   Cases_Asian Cases_AIAN Cases_NHPI Cases_Multiracial  ... Deaths_LatinX  \
# 0          67        282         76                61  ...             0
# 1         267          0          0                 0  ...             0
# 2         498        101       1985                 0  ...             0
# 3           0          0          0                 0  ...             0
# 4        1096       9085          0                 0  ...           786
#
#   Deaths_Asian Deaths_AIAN Deaths_NHPI Deaths_Multiracial Deaths_Other  \
# 0            2           4           1                  0            0
# 1            4           0           0                  0           27
# 2            6           0          30                  0           27
# 3            0           0           0                  0            0
# 4           32         394           0                  0           53
#
#   Deaths_Unknown Deaths_Ethnicity_Hispanic Deaths_Ethnicity_NonHispanic  \
# 0              1                         0                           18
# 1            100                        45                         1126
# 2              3                        41                          336
# 3              0                         0                            0
# 4            495                       786                         1693
#
#   Deaths_Ethnicity_Unknown
# 0                        1
# 1                      193
# 2                        3
# 3                        0
# 4                      495
#
# [5 rows x 28 columns]

# %%
type(covid_tracker_df['Cases_Total'][0])
# Out:
# str

# %%
covid_tracker_df['Cases_Total']=covid_tracker_df['Cases_Total'].astype(int)
covid_tracker_df['Cases_White'] = covid_tracker_df['Cases_White'].astype(int)
covid_tracker_df['Cases_Black'] = covid_tracker_df['Cases_Black'].astype(int)
covid_tracker_df['Cases_LatinX'] = covid_tracker_df['Cases_LatinX'].astype(int)
covid_tracker_df['Cases_Asian'] = covid_tracker_df['Cases_Asian'].astype(int)
covid_tracker_df['Cases_AIAN'] = covid_tracker_df['Cases_AIAN'].astype(int)
covid_tracker_df['Cases_NHPI'] = covid_tracker_df['Cases_NHPI'].astype(int)
covid_tracker_df['Cases_Multiracial'] = covid_tracker_df['Cases_Multiracial'].astype(int)
covid_tracker_df['Cases_Other'] = covid_tracker_df['Cases_Other'].astype(int)
covid_tracker_df['Cases_Unknown'] = covid_tracker_df['Cases_Unknown'].astype(int)
covid_tracker_df['Cases_Ethnicity_Hispanic'] = covid_tracker_df['Cases_Ethnicity_Hispanic'].astype(int)
covid_tracker_df['Cases_Ethnicity_NonHispanic'] = covid_tracker_df['Cases_Ethnicity_NonHispanic'].astype(int)
covid_tracker_df['Cases_Ethnicity_Unknown'] = covid_tracker_df['Cases_Ethnicity_Unknown'].astype(int)
covid_tracker_df['Deaths_Total'] = covid_tracker_df['Deaths_Total'].astype(int)
covid_tracker_df['Deaths_White'] = covid_tracker_df['Deaths_White'].astype(int)
covid_tracker_df['Deaths_Black'] = covid_tracker_df['Deaths_Black'].astype(int)
covid_tracker_df['Deaths_LatinX'] = covid_tracker_df['Deaths_LatinX'].astype(int)
covid_tracker_df['Deaths_Asian'] = covid_tracker_df['Deaths_Asian'].astype(int)
covid_tracker_df['Deaths_AIAN'] = covid_tracker_df['Deaths_AIAN'].astype(int)
covid_tracker_df['Deaths_NHPI'] = covid_tracker_df['Deaths_NHPI'].astype(int)
covid_tracker_df['Deaths_Multiracial'] = covid_tracker_df['Deaths_Multiracial'].astype(int)
covid_tracker_df['Deaths_Other'] = covid_tracker_df['Deaths_Other'].astype(int)
covid_tracker_df['Deaths_Unknown'] = covid_tracker_df['Deaths_Unknown'].astype(int)
covid_tracker_df['Deaths_Ethnicity_Hispanic'] = covid_tracker_df['Deaths_Ethnicity_Hispanic'].astype(int)
covid_tracker_df['Deaths_Ethnicity_NonHispanic'] = covid_tracker_df['Deaths_Ethnicity_NonHispanic'].astype(int)
covid_tracker_df['Deaths_Ethnicity_Unknown'] = covid_tracker_df['Deaths_Ethnicity_Unknown'].astype(int)

# %%
type(covid_tracker_df['Cases_Total'][0])
# Out:
# numpy.int64

# %%
# Export the clean covid tracker data into a csv
covid_tracker_df.to_csv("../data/race_data_tracker.csv",encoding='utf-8', index=False)
